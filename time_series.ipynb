# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/sp500_stocks.csv')

df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)
#sort by date
df.sort_values(by='Date', inplace=True)
df.head()
# Out:
#            Symbol  Adj Close      Close       High        Low       Open  \
# Date
# 2010-01-04    MMM  53.295372  83.019997  83.449997  82.669998  83.089996
# 2010-01-04     IP  14.833630  25.383270  25.635422  25.252525  25.392611
# 2010-01-04    CMG  87.839996  87.839996  89.599998  87.180000  89.599998
# 2010-01-04   REGN  24.629999  24.629999  24.850000  23.969999  24.240000
# 2010-01-04    AMD   9.700000   9.700000   9.900000   9.680000   9.790000
#
#                 Volume
# Date
# 2010-01-04   3043700.0
# 2010-01-04   4260864.0
# 2010-01-04    313900.0
# 2010-01-04    510300.0
# 2010-01-04  18748700.0

# %%
#Time series and rolling averages plotted
MMM = df[df['Symbol']=='MMM']
#df['Volume'].plot(label='High',figsize=(16,8))
#25 day rolling mean
MMM['Close'].plot(label='Close',figsize=(16,8))

MMM['Close'].rolling(window=25).mean().plot(label='25 Day Avg')
MMM['Close'].rolling(window=50).mean().plot(label='50 Day Avg')
MMM['Close'].rolling(window=200).mean().plot(label='200 Day Avg')


plt.title('MMM Close Price')
plt.legend()
plt.show()

# %%
#make train and test data
train = df['S&P500'].loc['2000-01-01':'2018-12-31']
test = df['S&P500'].loc['2019-01-01':]

#plot train and test data
train.plot()
test.plot()
# Out:
# <Axes: xlabel='Date'>
