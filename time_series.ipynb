# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/sp500_stocks.csv')

df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)
df.head()
# Out:
#            Symbol  Adj Close      Close       High        Low       Open  \
# Date
# 2010-01-04    MMM  53.295372  83.019997  83.449997  82.669998  83.089996
# 2010-01-05    MMM  52.961571  82.500000  83.230003  81.699997  82.800003
# 2010-01-06    MMM  53.712666  83.669998  84.599998  83.510002  83.879997
# 2010-01-07    MMM  53.751186  83.730003  83.760002  82.120003  83.320000
# 2010-01-08    MMM  54.129948  84.320000  84.320000  83.300003  83.690002
#
#                Volume
# Date
# 2010-01-04  3043700.0
# 2010-01-05  2847000.0
# 2010-01-06  5268500.0
# 2010-01-07  4470100.0
# 2010-01-08  3405800.0

# %%
#Time series and rolling averages plotted

df['Volume'].plot(label='High',figsize=(16,8))
#25 day rolling mean
df['Volume'].rolling(window=25).mean().plot(label='25 Day Avg')
df['Volume'].rolling(window=50).mean().plot(label='50 Day Avg')
df['Volume'].rolling(window=100).mean().plot(label='100 Day Avg')

plt.legend()
plt.show()

# %%
#make train and test data
train = df['S&P500'].loc['2000-01-01':'2018-12-31']
test = df['S&P500'].loc['2019-01-01':]

#plot train and test data
train.plot()
test.plot()
# Out:
# <Axes: xlabel='Date'>
